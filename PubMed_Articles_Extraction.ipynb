# %% [markdown]
# <a href="https://colab.research.google.com/github/RehanKhan-007/NLP/blob/main/PubMed_Articles_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install metapub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting metapub
#   Downloading metapub-0.5.5.tar.gz (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 KB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from metapub) (57.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from metapub) (4.9.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from metapub) (2.25.1)
# Collecting eutils
#   Downloading eutils-0.6.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 KB 3.4 MB/s eta 0:00:00
# Collecting habanero
#   Downloading habanero-1.2.3-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from metapub) (0.8.10)
# Collecting cssselect
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 15.8 MB/s eta 0:00:00
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from metapub) (1.15.0)
# Collecting tox
#   Downloading tox-4.4.6-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.0/149.0 KB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: pytest in /usr/local/lib/python3.8/dist-packages (from metapub) (3.6.4)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 5.8 MB/s eta 0:00:00
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.20.9-py3-none-any.whl (9.4 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from eutils->metapub) (2022.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from habanero->metapub) (4.64.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->metapub) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->metapub) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->metapub) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->metapub) (1.26.14)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from pytest->metapub) (22.2.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest->metapub) (9.1.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.8/dist-packages (from pytest->metapub) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.8/dist-packages (from pytest->metapub) (1.4.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from pytest->metapub) (1.11.0)
# Collecting Levenshtein==0.20.9
#   Downloading Levenshtein-0.20.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 KB 22.8 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock>=3.9 in /usr/local/lib/python3.8/dist-packages (from tox->metapub) (3.9.0)
# Collecting tox
#   Downloading tox-4.4.5-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 KB 15.2 MB/s eta 0:00:00
#   Downloading tox-4.4.4-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 KB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from tox->metapub) (5.3.0)
#   Downloading tox-4.4.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 KB 16.1 MB/s eta 0:00:00
#   Downloading tox-4.4.2-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 KB 16.4 MB/s eta 0:00:00
#   Downloading tox-4.4.1-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 KB 16.2 MB/s eta 0:00:00
#   Downloading tox-4.4.0-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 KB 18.1 MB/s eta 0:00:00
#   Downloading tox-4.3.5-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.7/147.7 KB 15.8 MB/s eta 0:00:00
#   Downloading tox-4.3.4-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 KB 18.0 MB/s eta 0:00:00
#   Downloading tox-4.3.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 KB 18.8 MB/s eta 0:00:00
#   Downloading tox-4.3.2-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 KB 18.6 MB/s eta 0:00:00
#   Downloading tox-4.3.1-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 KB 19.3 MB/s eta 0:00:00
#   Downloading tox-4.3.0-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.3/147.3 KB 19.3 MB/s eta 0:00:00
#   Downloading tox-4.2.8-py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.1/146.1 KB 15.5 MB/s eta 0:00:00
#   Downloading tox-4.2.7-py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 17.4 MB/s eta 0:00:00
#   Downloading tox-4.2.6-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 KB 18.9 MB/s eta 0:00:00
# Collecting pyproject-api>=1.2.1
#   Downloading pyproject_api-1.5.0-py3-none-any.whl (12 kB)
# Collecting tox
#   Downloading tox-4.2.5-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 KB 17.8 MB/s eta 0:00:00
#   Downloading tox-4.2.4-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 KB 19.8 MB/s eta 0:00:00
#   Downloading tox-4.2.3-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 KB 20.0 MB/s eta 0:00:00
#   Downloading tox-4.2.2-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.5/145.5 KB 18.1 MB/s eta 0:00:00
#   Downloading tox-4.2.1-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 KB 18.3 MB/s eta 0:00:00
#   Downloading tox-4.2.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 KB 19.3 MB/s eta 0:00:00
#   Downloading tox-4.1.3-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.1/145.1 KB 19.9 MB/s eta 0:00:00
#   Downloading tox-4.1.2-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 KB 18.5 MB/s eta 0:00:00
#   Downloading tox-4.1.1-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 KB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.6 in /usr/local/lib/python3.8/dist-packages (from tox->metapub) (3.0.0)
#   Downloading tox-4.1.0-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 KB 19.0 MB/s eta 0:00:00
#   Downloading tox-4.0.19-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 KB 19.3 MB/s eta 0:00:00
#   Downloading tox-4.0.18-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 KB 18.3 MB/s eta 0:00:00
#   Downloading tox-4.0.17-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 KB 19.5 MB/s eta 0:00:00
#   Downloading tox-4.0.16-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 KB 19.7 MB/s eta 0:00:00
#   Downloading tox-4.0.15-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 KB 18.2 MB/s eta 0:00:00
#   Downloading tox-4.0.14-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 KB 17.5 MB/s eta 0:00:00
#   Downloading tox-4.0.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 KB 17.4 MB/s eta 0:00:00
#   Downloading tox-4.0.12-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 KB 17.7 MB/s eta 0:00:00
#   Downloading tox-4.0.11-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 KB 18.0 MB/s eta 0:00:00
#   Downloading tox-4.0.10-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.8/141.8 KB 17.2 MB/s eta 0:00:00
#   Downloading tox-4.0.9-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.7/141.7 KB 18.4 MB/s eta 0:00:00
#   Downloading tox-4.0.8-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.4/141.4 KB 17.3 MB/s eta 0:00:00
#   Downloading tox-4.0.7-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 KB 17.1 MB/s eta 0:00:00
#   Downloading tox-4.0.6-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 KB 15.4 MB/s eta 0:00:00
#   Downloading tox-4.0.5-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 KB 17.1 MB/s eta 0:00:00
#   Downloading tox-4.0.4-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.7/140.7 KB 12.6 MB/s eta 0:00:00
#   Downloading tox-4.0.3-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 KB 13.1 MB/s eta 0:00:00
#   Downloading tox-4.0.2-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 KB 12.9 MB/s eta 0:00:00
#   Downloading tox-4.0.1-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 KB 15.2 MB/s eta 0:00:00
#   Downloading tox-4.0.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 KB 16.9 MB/s eta 0:00:00
#   Downloading tox-3.28.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=14 in /usr/local/lib/python3.8/dist-packages (from tox->metapub) (23.0)
#   Downloading tox-3.27.1-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 KB 11.3 MB/s eta 0:00:00
#   Downloading tox-3.27.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.6/86.6 KB 10.9 MB/s eta 0:00:00
#   Downloading tox-3.26.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.3/86.3 KB 11.1 MB/s eta 0:00:00
#   Downloading tox-3.25.1-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.8/dist-packages (from tox->metapub) (0.10.2)
#   Downloading tox-3.25.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 KB 9.8 MB/s eta 0:00:00
#   Downloading tox-3.24.5-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 10.5 MB/s eta 0:00:00
#   Downloading tox-3.24.4-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 10.3 MB/s eta 0:00:00
#   Downloading tox-3.24.3-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 10.9 MB/s eta 0:00:00
#   Downloading tox-3.24.2-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 11.0 MB/s eta 0:00:00
#   Downloading tox-3.24.1-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 10.8 MB/s eta 0:00:00
#   Downloading tox-3.24.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 KB 9.4 MB/s eta 0:00:00
#   Downloading tox-3.23.1-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 KB 8.4 MB/s eta 0:00:00
#   Downloading tox-3.23.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 KB 9.4 MB/s eta 0:00:00
#   Downloading tox-3.22.0-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 KB 10.1 MB/s eta 0:00:00
#   Downloading tox-3.21.4-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 KB 9.7 MB/s eta 0:00:00
#   Downloading tox-3.21.3-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 KB 6.4 MB/s eta 0:00:00
#   Downloading tox-3.21.2-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 KB 9.8 MB/s eta 0:00:00
#   Downloading tox-3.21.1-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 KB 9.4 MB/s eta 0:00:00
#   Downloading tox-3.21.0-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 10.8 MB/s eta 0:00:00
#   Downloading tox-3.20.1-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 KB 9.4 MB/s eta 0:00:00
#   Downloading tox-3.20.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 KB 9.6 MB/s eta 0:00:00
#   Downloading tox-3.19.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.3/83.3 KB 9.6 MB/s eta 0:00:00
#   Downloading tox-3.18.1-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 KB 9.4 MB/s eta 0:00:00
#   Downloading tox-3.18.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 KB 10.7 MB/s eta 0:00:00
#   Downloading tox-3.17.1-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 KB 10.4 MB/s eta 0:00:00
#   Downloading tox-3.17.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 KB 8.5 MB/s eta 0:00:00
#   Downloading tox-3.16.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 KB 10.4 MB/s eta 0:00:00
#   Downloading tox-3.15.2-py2.py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.1/137.1 KB 15.9 MB/s eta 0:00:00
#   Downloading tox-3.15.1-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 11.1 MB/s eta 0:00:00
#   Downloading tox-3.15.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 10.1 MB/s eta 0:00:00
#   Downloading tox-3.14.6-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 KB 10.6 MB/s eta 0:00:00
#   Downloading tox-3.14.5-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 KB 12.2 MB/s eta 0:00:00
# Collecting virtualenv>=16.0.0
#   Downloading virtualenv-20.20.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 89.9 MB/s eta 0:00:00
# Collecting tox
#   Downloading tox-3.14.4-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 10.7 MB/s eta 0:00:00
#   Downloading tox-3.14.3-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 KB 10.9 MB/s eta 0:00:00
#   Downloading tox-3.14.2-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 KB 10.5 MB/s eta 0:00:00
#   Downloading tox-3.14.1-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 KB 11.3 MB/s eta 0:00:00
#   Downloading tox-3.14.0-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 KB 11.5 MB/s eta 0:00:00
#   Downloading tox-3.13.2-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 11.5 MB/s eta 0:00:00
# Collecting importlib-metadata<1,>=0.12
#   Downloading importlib_metadata-0.23-py2.py3-none-any.whl (28 kB)
# Collecting tox
#   Downloading tox-3.13.1-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 10.0 MB/s eta 0:00:00
#   Downloading tox-3.13.0-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 9.7 MB/s eta 0:00:00
#   Downloading tox-3.12.1-py2.py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 KB 9.0 MB/s eta 0:00:00
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 41.1 MB/s eta 0:00:00
# Building wheels for collected packages: metapub, docopt
#   Building wheel for metapub (setup.py) ... done
#   Created wheel for metapub: filename=metapub-0.5.5-py3-none-any.whl size=135370 sha256=6cc17ecaa7098318d77becb5a9e2030708ec22b30b2e7c860a98386db04384fb
#   Stored in directory: /root/.cache/pip/wheels/37/f4/78/7d3fe99fd30c543604765b7aa262c812c5bed406b2edd428ff
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=9812ad78c260b682ccadaf55419e9e6d383768bd5e5a5b3630dfcdef8abb3e3e
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built metapub docopt
# Installing collected packages: docopt, distlib, virtualenv, unidecode, rapidfuzz, humanfriendly, cssselect, tox, Levenshtein, habanero, eutils, coloredlogs, python-Levenshtein, metapub
# Successfully installed Levenshtein-0.20.9 coloredlogs-15.0.1 cssselect-1.2.0 distlib-0.3.6 docopt-0.6.2 eutils-0.6.0 habanero-1.2.3 humanfriendly-10.0 metapub-0.5.5 python-Levenshtein-0.20.9 rapidfuzz-2.13.7 tox-3.12.1 unidecode-1.3.6 virtualenv-20.20.0

# %%
import pandas as pd
# Out:
# 2023-03-04 04:16:01 a25b8b1c13e7 numexpr.utils[274] INFO NumExpr defaulting to 2 threads.

# %%
#initialise the keyword to be searched and number of articles to be retrieved

keyword="diabetes and phytocompounds"
num_of_articles=10

# %%
from metapub import PubMedFetcher
fetch = PubMedFetcher()

# get the  PMID for first 3 articles with keyword sepsis
pmids = fetch.pmids_for_query(keyword, retmax=num_of_articles)

# get  articles
articles = {}
for pmid in pmids:
    articles[pmid] = fetch.article_by_pmid(pmid)
# Out:
# 2023-03-04 04:14:54 a25b8b1c13e7 metapub.config[274] WARNING NCBI_API_KEY was not set.

# %%
# get title for each article:
titles = {}
for pmid in pmids:
    titles[pmid] = fetch.article_by_pmid(pmid).title
Title = pd.DataFrame(list(titles.items()),columns = ['pmid','Title'])
Title

# get abstract for each article:
abstracts = {}
for pmid in pmids:
    abstracts[pmid] = fetch.article_by_pmid(pmid).abstract
Abstract = pd.DataFrame(list(abstracts.items()),columns = ['pmid','Abstract'])
Abstract
# Out:
#        pmid                                           Abstract
# 0  36867758  The unacceptable high mortality of severe infe...
# 1  36867755                                               None
# 2  36867602  OBJECTIVE: To compare results from facility-le...

# %%
import pandas as pd
#initialise the keyword to be searched and number of articles to be retrieved

keyword="diabetes and phytocompounds"
num_of_articles=10

from metapub import PubMedFetcher
fetch = PubMedFetcher()

# get the  PMID for first 3 articles with keyword sepsis
pmids = fetch.pmids_for_query(keyword, retmax=num_of_articles)

# get  articles
articles = {}
for pmid in pmids:
    articles[pmid] = fetch.article_by_pmid(pmid)

# get title for each article:
titles = {}
for pmid in pmids:
    titles[pmid] = fetch.article_by_pmid(pmid).title
Title = pd.DataFrame(list(titles.items()),columns = ['pmid','Title'])
Title

# get abstract for each article:
abstracts = {}
for pmid in pmids:
    abstracts[pmid] = fetch.article_by_pmid(pmid).abstract
Abstract = pd.DataFrame(list(abstracts.items()),columns = ['pmid','Abstract'])
Abstract

# get author for each article:
authors = {}
for pmid in pmids:
    authors[pmid] = fetch.article_by_pmid(pmid).authors
Author = pd.DataFrame(list(authors.items()),columns = ['pmid','Author'])
Author

# get year for each article:
years = {}
for pmid in pmids:
    years[pmid] = fetch.article_by_pmid(pmid).year
Year = pd.DataFrame(list(years.items()),columns = ['pmid','Year'])
Year

# get volume for each article:
volumes = {}
for pmid in pmids:
    volumes[pmid] = fetch.article_by_pmid(pmid).volume
Volume = pd.DataFrame(list(volumes.items()),columns = ['pmid','Volume'])
Volume

# get issue for each article:
issues = {}
for pmid in pmids:
    issues[pmid] = fetch.article_by_pmid(pmid).issue
Issue = pd.DataFrame(list(issues.items()),columns = ['pmid','Issue'])
Issue

# get journal for each article:
journals = {}
for pmid in pmids:
    journals[pmid] = fetch.article_by_pmid(pmid).journal
Journal = pd.DataFrame(list(journals.items()),columns = ['pmid','Journal'])
Journal

# get citation for each article:
citations = {}
for pmid in pmids:
    citations[pmid] = fetch.article_by_pmid(pmid).citation
Citation = pd.DataFrame(list(citations.items()),columns = ['pmid','Citation'])
Citation

links={}
for pmid in pmids:
    links[pmid] = "https://pubmed.ncbi.nlm.nih.gov/"+pmid+"/"
Link = pd.DataFrame(list(links.items()),columns = ['pmid','Link'])
Link

data_frames = [Title,Abstract,Author,Year,Volume,Issue,Journal,Citation,Link]
from functools import reduce
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['pmid'],
                                            how='outer'), data_frames)
df_merged
# Out:
#        pmid                                              Title  \
# 0  36716329  Integrated network pharmacology and molecular ...
# 1  36654462  Phytoconstituents Based Nanomedicines for the ...
# 2  36582536  Elucidating type 2 diabetes mellitus risk fact...
# 3  36568059  Cytotoxicity and phytochemical profiles of Phy...
# 4  36558951  Antiviral Effect of Stenocline ericoides DC. a...
# 5  36510695  Identification and screening of potential inhi...
# 6  36501387  Traditional Knowledge, Phytochemistry, and Bio...
# 7  36431765  Evaluation of the Antifungal, Antioxidant, and...
# 8  36415094  Health Benefits, Therapeutic Applications, and...
# 9  36297570  An Overview of Herbal-Based Antidiabetic Drug ...
#
#                                             Abstract  \
# 0  The current study investigates the effectivene...
# 1  Diabetes mellitus (DM) is a life-threatening m...
# 2                                               None
# 3        Out of numerous reported medicinal plants,
# 4  Dengue and Zika viruses are identified as the ...
# 5  Type 2 diabetes mellitus (T2DM) is the inabili...
# 6                                               None
# 7  Essential oils (EOs) have gained immense popul...
# 8  BACKGROUND: Herbal medicine and its derived pr...
# 9  Diabetes is a metabolic pathology with chronic...
#
#                                               Author  Year Volume Issue  \
# 0  [Maradesha T, Martiz RM, Patil SM, Prasad A, B...  2023     18     1
# 1                                [Jadhav S, Yadav A]  2023   None  None
# 2  [DasNandy A, Patil VS, Hegde HV, Harish DR, Ro...  2022     13  None
# 3  [Quranayati Q, Iqhrammullah M, Saidi N, Nurlia...  2022     13     4
# 4  [Ramiharimanana FD, Haddad JG, Andrianavalonir...  2022     15    12
# 5                        [Hazra S, Aziz A, Sharma S]  2022   None  None
# 6  [Taha D, El Hajjaji S, Mourabit Y, Bouyahya A,...  2022     11    23
# 7  [Sharma N, Gupta N, Orfali R, Kumar V, Patel C...  2022     27    22
# 8                                         [Patel DK]  2022   None  None
# 9  [Kambale EK, Quetin-Leclercq J, Memvanga PB, B...  2022     14    10
#
#                                    Journal  \
# 0                                 PLoS One
# 1                        Pharm Nanotechnol
# 2                          Front Pharmacol
# 3                  J Adv Pharm Technol Res
# 4                  Pharmaceuticals (Basel)
# 5                      J Biomol Struct Dyn
# 6                           Plants (Basel)
# 7                                Molecules
# 8  Endocr Metab Immune Disord Drug Targets
# 9                            Pharmaceutics
#
#                                             Citation  \
# 0  Maradesha T, et al. Integrated network pharmac...
# 1  Jadhav S and Yadav A. Phytoconstituents Based ...
# 2  DasNandy A, et al. Elucidating type 2 diabetes...
# 3  Quranayati Q, et al. Cytotoxicity and phytoche...
# 4  Ramiharimanana FD, et al. Antiviral Effect of ...
# 5  Hazra S, et al. Identification and screening o...
# 6  Taha D, et al. Traditional Knowledge, Phytoche...
# 7  Sharma N, et al. Evaluation of the Antifungal,...
# 8  Patel DK. Health Benefits, Therapeutic Applica...
# 9  Kambale EK, et al. An Overview of Herbal-Based...
#
#                                         Link
# 0  https://pubmed.ncbi.nlm.nih.gov/36716329/
# 1  https://pubmed.ncbi.nlm.nih.gov/36654462/
# 2  https://pubmed.ncbi.nlm.nih.gov/36582536/
# 3  https://pubmed.ncbi.nlm.nih.gov/36568059/
# 4  https://pubmed.ncbi.nlm.nih.gov/36558951/
# 5  https://pubmed.ncbi.nlm.nih.gov/36510695/
# 6  https://pubmed.ncbi.nlm.nih.gov/36501387/
# 7  https://pubmed.ncbi.nlm.nih.gov/36431765/
# 8  https://pubmed.ncbi.nlm.nih.gov/36415094/
# 9  https://pubmed.ncbi.nlm.nih.gov/36297570/
