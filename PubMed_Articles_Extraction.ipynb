# %% [markdown]
# <a href="https://colab.research.google.com/github/RehanKhan-007/NLP/blob/main/PubMed_Articles_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install metapub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting metapub
#   Downloading metapub-0.5.5.tar.gz (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 KB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from metapub) (57.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from metapub) (4.9.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from metapub) (2.25.1)
# Collecting eutils
#   Downloading eutils-0.6.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 KB 2.8 MB/s eta 0:00:00
# Collecting habanero
#   Downloading habanero-1.2.3-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from metapub) (0.8.10)
# Collecting cssselect
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 13.1 MB/s eta 0:00:00
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from metapub) (1.15.0)
# Collecting tox
#   Downloading tox-4.4.7-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.0/149.0 KB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from metapub) (3.6.4)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 2.8 MB/s eta 0:00:00
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.20.9-py3-none-any.whl (9.4 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from eutils->metapub) (2022.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from habanero->metapub) (4.65.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->metapub) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->metapub) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->metapub) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->metapub) (1.26.14)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.9/dist-packages (from pytest->metapub) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from pytest->metapub) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->metapub) (9.1.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from pytest->metapub) (22.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.9/dist-packages (from pytest->metapub) (1.4.1)
# Collecting Levenshtein==0.20.9
#   Downloading Levenshtein-0.20.9-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 KB 5.0 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=5.3 in /usr/local/lib/python3.9/dist-packages (from tox->metapub) (5.3.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from tox->metapub) (2.0.1)
# Collecting virtualenv>=20.17.1
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 24.9 MB/s eta 0:00:00
# Collecting tox
#   Downloading tox-4.4.6-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.0/149.0 KB 8.4 MB/s eta 0:00:00
#   Downloading tox-4.4.5-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 KB 12.8 MB/s eta 0:00:00
#   Downloading tox-4.4.4-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 KB 8.3 MB/s eta 0:00:00
#   Downloading tox-4.4.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 KB 8.6 MB/s eta 0:00:00
#   Downloading tox-4.4.2-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 KB 6.5 MB/s eta 0:00:00
#   Downloading tox-4.4.1-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 KB 13.2 MB/s eta 0:00:00
#   Downloading tox-4.4.0-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 KB 11.9 MB/s eta 0:00:00
#   Downloading tox-4.3.5-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.7/147.7 KB 6.7 MB/s eta 0:00:00
#   Downloading tox-4.3.4-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 KB 4.3 MB/s eta 0:00:00
#   Downloading tox-4.3.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 KB 11.4 MB/s eta 0:00:00
#   Downloading tox-4.3.2-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 KB 12.0 MB/s eta 0:00:00
#   Downloading tox-4.3.1-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 KB 4.9 MB/s eta 0:00:00
#   Downloading tox-4.3.0-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.3/147.3 KB 1.7 MB/s eta 0:00:00
#   Downloading tox-4.2.8-py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.1/146.1 KB 11.7 MB/s eta 0:00:00
#   Downloading tox-4.2.7-py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 6.9 MB/s eta 0:00:00
#   Downloading tox-4.2.6-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 KB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.9/dist-packages (from tox->metapub) (23.0)
# Requirement already satisfied: platformdirs>=2.6.2 in /usr/local/lib/python3.9/dist-packages (from tox->metapub) (3.1.0)
#   Downloading tox-4.2.5-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 KB 9.8 MB/s eta 0:00:00
#   Downloading tox-4.2.4-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 KB 10.4 MB/s eta 0:00:00
#   Downloading tox-4.2.3-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 KB 12.7 MB/s eta 0:00:00
#   Downloading tox-4.2.2-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.5/145.5 KB 7.3 MB/s eta 0:00:00
#   Downloading tox-4.2.1-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 KB 5.2 MB/s eta 0:00:00
#   Downloading tox-4.2.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 KB 9.4 MB/s eta 0:00:00
#   Downloading tox-4.1.3-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.1/145.1 KB 12.5 MB/s eta 0:00:00
#   Downloading tox-4.1.2-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 KB 7.7 MB/s eta 0:00:00
#   Downloading tox-4.1.1-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 KB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock>=3.8.2 in /usr/local/lib/python3.9/dist-packages (from tox->metapub) (3.9.0)
#   Downloading tox-4.1.0-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 KB 11.8 MB/s eta 0:00:00
#   Downloading tox-4.0.19-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 KB 11.1 MB/s eta 0:00:00
#   Downloading tox-4.0.18-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 KB 10.9 MB/s eta 0:00:00
#   Downloading tox-4.0.17-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 KB 10.1 MB/s eta 0:00:00
#   Downloading tox-4.0.16-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 KB 10.8 MB/s eta 0:00:00
#   Downloading tox-4.0.15-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 KB 10.7 MB/s eta 0:00:00
#   Downloading tox-4.0.14-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 KB 10.8 MB/s eta 0:00:00
#   Downloading tox-4.0.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 KB 13.7 MB/s eta 0:00:00
#   Downloading tox-4.0.12-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 KB 9.5 MB/s eta 0:00:00
#   Downloading tox-4.0.11-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 KB 577.6 kB/s eta 0:00:00
#   Downloading tox-4.0.10-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.8/141.8 KB 10.2 MB/s eta 0:00:00
#   Downloading tox-4.0.9-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.7/141.7 KB 9.5 MB/s eta 0:00:00
#   Downloading tox-4.0.8-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.4/141.4 KB 8.5 MB/s eta 0:00:00
#   Downloading tox-4.0.7-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 KB 11.9 MB/s eta 0:00:00
#   Downloading tox-4.0.6-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 KB 7.4 MB/s eta 0:00:00
#   Downloading tox-4.0.5-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 KB 8.8 MB/s eta 0:00:00
#   Downloading tox-4.0.4-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.7/140.7 KB 9.5 MB/s eta 0:00:00
#   Downloading tox-4.0.3-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 KB 10.2 MB/s eta 0:00:00
#   Downloading tox-4.0.2-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 KB 10.2 MB/s eta 0:00:00
#   Downloading tox-4.0.1-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 KB 10.0 MB/s eta 0:00:00
#   Downloading tox-4.0.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 KB 9.4 MB/s eta 0:00:00
#   Downloading tox-3.28.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 6.0 MB/s eta 0:00:00
#   Downloading tox-3.27.1-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 KB 6.4 MB/s eta 0:00:00
#   Downloading tox-3.27.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.6/86.6 KB 6.5 MB/s eta 0:00:00
#   Downloading tox-3.26.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.3/86.3 KB 6.7 MB/s eta 0:00:00
#   Downloading tox-3.25.1-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 8.4 MB/s eta 0:00:00
#   Downloading tox-3.25.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 KB 7.6 MB/s eta 0:00:00
#   Downloading tox-3.24.5-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 5.0 MB/s eta 0:00:00
#   Downloading tox-3.24.4-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 4.5 MB/s eta 0:00:00
#   Downloading tox-3.24.3-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 6.8 MB/s eta 0:00:00
#   Downloading tox-3.24.2-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 6.3 MB/s eta 0:00:00
#   Downloading tox-3.24.1-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 5.8 MB/s eta 0:00:00
#   Downloading tox-3.24.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 KB 5.6 MB/s eta 0:00:00
#   Downloading tox-3.23.1-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 KB 6.0 MB/s eta 0:00:00
#   Downloading tox-3.23.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 KB 7.0 MB/s eta 0:00:00
#   Downloading tox-3.22.0-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 KB 8.9 MB/s eta 0:00:00
#   Downloading tox-3.21.4-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 KB 8.8 MB/s eta 0:00:00
#   Downloading tox-3.21.3-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 KB 8.4 MB/s eta 0:00:00
#   Downloading tox-3.21.2-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 KB 5.1 MB/s eta 0:00:00
#   Downloading tox-3.21.1-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 KB 8.6 MB/s eta 0:00:00
#   Downloading tox-3.21.0-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 8.0 MB/s eta 0:00:00
#   Downloading tox-3.20.1-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 KB 8.1 MB/s eta 0:00:00
#   Downloading tox-3.20.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 KB 8.7 MB/s eta 0:00:00
#   Downloading tox-3.19.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.3/83.3 KB 9.1 MB/s eta 0:00:00
#   Downloading tox-3.18.1-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 KB 8.3 MB/s eta 0:00:00
#   Downloading tox-3.18.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 KB 10.3 MB/s eta 0:00:00
#   Downloading tox-3.17.1-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 KB 9.5 MB/s eta 0:00:00
#   Downloading tox-3.17.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 KB 10.5 MB/s eta 0:00:00
#   Downloading tox-3.16.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 KB 9.0 MB/s eta 0:00:00
#   Downloading tox-3.15.2-py2.py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.1/137.1 KB 15.3 MB/s eta 0:00:00
#   Downloading tox-3.15.1-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 9.9 MB/s eta 0:00:00
#   Downloading tox-3.15.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.9/dist-packages (from tox->metapub) (0.10.2)
#   Downloading tox-3.14.6-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 KB 9.1 MB/s eta 0:00:00
#   Downloading tox-3.14.5-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 KB 8.1 MB/s eta 0:00:00
#   Downloading tox-3.14.4-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 8.7 MB/s eta 0:00:00
#   Downloading tox-3.14.3-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 KB 9.9 MB/s eta 0:00:00
#   Downloading tox-3.14.2-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 KB 9.8 MB/s eta 0:00:00
#   Downloading tox-3.14.1-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 KB 9.9 MB/s eta 0:00:00
#   Downloading tox-3.14.0-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 KB 8.4 MB/s eta 0:00:00
#   Downloading tox-3.13.2-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 9.2 MB/s eta 0:00:00
# Collecting importlib-metadata<1,>=0.12
#   Downloading importlib_metadata-0.23-py2.py3-none-any.whl (28 kB)
# Collecting tox
#   Downloading tox-3.13.1-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 8.5 MB/s eta 0:00:00
#   Downloading tox-3.13.0-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 9.1 MB/s eta 0:00:00
#   Downloading tox-3.12.1-py2.py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 KB 8.4 MB/s eta 0:00:00
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 38.1 MB/s eta 0:00:00
# Building wheels for collected packages: metapub, docopt
#   Building wheel for metapub (setup.py) ... done
#   Created wheel for metapub: filename=metapub-0.5.5-py3-none-any.whl size=135370 sha256=f5b9a6a00e0a69d48355bbafd6abcb74eea19f8deb98a9bc5df5d6d176e63e07
#   Stored in directory: /root/.cache/pip/wheels/ed/48/c7/e9049c6b84a2ca11fa70c98fac7aabb5ea67be77f0863e8ddf
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=869636ccb532933d8c6ade3959b46cd414aa0838d1a489749670a27e84336e43
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built metapub docopt
# Installing collected packages: docopt, distlib, virtualenv, unidecode, rapidfuzz, humanfriendly, cssselect, tox, Levenshtein, habanero, eutils, coloredlogs, python-Levenshtein, metapub
# Successfully installed Levenshtein-0.20.9 coloredlogs-15.0.1 cssselect-1.2.0 distlib-0.3.6 docopt-0.6.2 eutils-0.6.0 habanero-1.2.3 humanfriendly-10.0 metapub-0.5.5 python-Levenshtein-0.20.9 rapidfuzz-2.13.7 tox-3.12.1 unidecode-1.3.6 virtualenv-20.21.0

# %%
import pandas as pd

# %%
#initialise the keyword to be searched and number of articles to be retrieved

keyword="medicinal plants and phytocompounds"
num_of_articles=10

# %%
from metapub import PubMedFetcher
fetch = PubMedFetcher()

# get the  PMID for first 3 articles with keyword medicinal plants and phytocompounds
pmids = fetch.pmids_for_query(keyword, retmax=num_of_articles)

# get  articles
articles = {}
for pmid in pmids:
    articles[pmid] = fetch.article_by_pmid(pmid)

# %%
# get title for each article:
titles = {}
for pmid in pmids:
    titles[pmid] = fetch.article_by_pmid(pmid).title
Title = pd.DataFrame(list(titles.items()),columns = ['pmid','Title'])
Title

# get abstract for each article:
abstracts = {}
for pmid in pmids:
    abstracts[pmid] = fetch.article_by_pmid(pmid).abstract
Abstract = pd.DataFrame(list(abstracts.items()),columns = ['pmid','Abstract'])
Abstract
# Out:
#        pmid                                           Abstract
# 0  36866556  BACKGROUND: Candidiasis is a common oral and v...
# 1  36839737                                               None
# 2  36837862  Inflammatory bowel diseases (IBDs) are related...
# 3  36771738  The island of Grande-Terre is a French oversea...
# 4  36771558  Antioxidants are important supplements for the...
# 5  36747936  Herbal medications are gaining popularity due ...
# 6  36675191  Paulownia spp. is a genus of trees in the Paul...
# 7  36672732  Cancer is one of the main causes of death worl...
# 8  36671402  Viruses are widely recognized as the primary c...
# 9  36644848                                               None

# %%
import pandas as pd
#initialise the keyword to be searched and number of articles to be retrieved

keyword="medicinal plants and phytocompounds"
num_of_articles=10

from metapub import PubMedFetcher
fetch = PubMedFetcher()

# get the  PMID for first 3 articles with keyword medicinal plants and phytocompounds
pmids = fetch.pmids_for_query(keyword, retmax=num_of_articles)

# get  articles
articles = {}
for pmid in pmids:
    articles[pmid] = fetch.article_by_pmid(pmid)

# get title for each article:
titles = {}
for pmid in pmids:
    titles[pmid] = fetch.article_by_pmid(pmid).title
Title = pd.DataFrame(list(titles.items()),columns = ['pmid','Title'])
Title

# get abstract for each article:
abstracts = {}
for pmid in pmids:
    abstracts[pmid] = fetch.article_by_pmid(pmid).abstract
Abstract = pd.DataFrame(list(abstracts.items()),columns = ['pmid','Abstract'])
Abstract

# get author for each article:
authors = {}
for pmid in pmids:
    authors[pmid] = fetch.article_by_pmid(pmid).authors
Author = pd.DataFrame(list(authors.items()),columns = ['pmid','Author'])
Author

# get year for each article:
years = {}
for pmid in pmids:
    years[pmid] = fetch.article_by_pmid(pmid).year
Year = pd.DataFrame(list(years.items()),columns = ['pmid','Year'])
Year

# get volume for each article:
volumes = {}
for pmid in pmids:
    volumes[pmid] = fetch.article_by_pmid(pmid).volume
Volume = pd.DataFrame(list(volumes.items()),columns = ['pmid','Volume'])
Volume

# get issue for each article:
issues = {}
for pmid in pmids:
    issues[pmid] = fetch.article_by_pmid(pmid).issue
Issue = pd.DataFrame(list(issues.items()),columns = ['pmid','Issue'])
Issue

# get journal for each article:
journals = {}
for pmid in pmids:
    journals[pmid] = fetch.article_by_pmid(pmid).journal
Journal = pd.DataFrame(list(journals.items()),columns = ['pmid','Journal'])
Journal

# get citation for each article:
citations = {}
for pmid in pmids:
    citations[pmid] = fetch.article_by_pmid(pmid).citation
Citation = pd.DataFrame(list(citations.items()),columns = ['pmid','Citation'])
Citation

links={}
for pmid in pmids:
    links[pmid] = "https://pubmed.ncbi.nlm.nih.gov/"+pmid+"/"
Link = pd.DataFrame(list(links.items()),columns = ['pmid','Link'])
Link

data_frames = [Title,Abstract,Author,Year,Volume,Issue,Journal,Citation,Link]
from functools import reduce
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['pmid'],
                                            how='outer'), data_frames)
df_merged
# Out:
#        pmid                                              Title  \
# 0  36866556  Anti-Candida and Antibiofilm Activity of Selec...
# 1  36839737  Polyphenolic Profile of Herniaria hemistemon A...
# 2  36837862  Effects of Medicinal Plants and Phytochemicals...
# 3  36771738  Medicinal Plants and Plant-Based Remedies in G...
# 4  36771558  Quali-Quantitative Fingerprinting of the Fruit...
# 5  36747936  In vitro antioxidant activities of Carissa edu...
# 6  36675191  Paulownia Organs as Interesting New Sources of...
# 7  36672732  An Overview of Potential Natural Photosensitiz...
# 8  36671402  Bioactivity and In Silico Studies of Isoquinol...
# 9  36644848  Discovery of potential phytochemicals as inhib...
#
#                                             Abstract  \
# 0  BACKGROUND: Candidiasis is a common oral and v...
# 1                                               None
# 2  Inflammatory bowel diseases (IBDs) are related...
# 3  The island of Grande-Terre is a French oversea...
# 4  Antioxidants are important supplements for the...
# 5  Herbal medications are gaining popularity due ...
# 6  Paulownia spp. is a genus of trees in the Paul...
# 7  Cancer is one of the main causes of death worl...
# 8  Viruses are widely recognized as the primary c...
# 9                                               None
#
#                                               Author  Year Volume Issue  \
# 0  [Karpiński TM, Ożarowski M, Seremak-Mrozikiewi...  2023     28     2
# 1  [Ghareeb MA, Sobeh M, Aboushousha T, Esmat M, ...  2023     15     2
# 2  [Laurindo LF, de Maio MC, Minniti G, de Góes C...  2023     13     2
# 3  [Courric E, Brinvilier D, Couderc P, Ponce-Mor...  2023     12     3
# 4  [Rakotonirina FMV, Donno D, Razafindrakoto ZR,...  2023     12     3
# 5        [Muruthi CW, Ngugi MP, Runo SM, Mwitari PG]  2023      9     1
# 6                     [Sławińska N, Zając J, Olas B]  2023     24     2
# 7  [Aziz B, Aziz I, Khurshid A, Raoufi E, Esfahan...  2023     11     1
# 8  [Sharma D, Sharma N, Manchanda N, Prasad SK, S...  2022     13     1
# 9  [Alamri MA, Tariq MH, Tahir Ul Qamar M, Alabba...  2023   None  None
#
#                       Journal  \
# 0  Front Biosci (Landmark Ed)
# 1               Pharmaceutics
# 2                 Metabolites
# 3              Plants (Basel)
# 4              Plants (Basel)
# 5                     Heliyon
# 6               Int J Mol Sci
# 7                Biomedicines
# 8                Biomolecules
# 9         J Biomol Struct Dyn
#
#                                             Citation  \
# 0  Karpiński TM, et al. Anti-Candida and Antibiof...
# 1  Ghareeb MA, et al. Polyphenolic Profile of Her...
# 2  Laurindo LF, et al. Effects of Medicinal Plant...
# 3  Courric E, et al. Medicinal Plants and Plant-B...
# 4  Rakotonirina FMV, et al. Quali-Quantitative Fi...
# 5  Muruthi CW, et al. In vitro antioxidant activi...
# 6  Sławińska N, et al. Paulownia Organs as Intere...
# 7  Aziz B, et al. An Overview of Potential Natura...
# 8  Sharma D, et al. Bioactivity and In Silico Stu...
# 9  Alamri MA, et al. Discovery of potential phyto...
#
#                                         Link
# 0  https://pubmed.ncbi.nlm.nih.gov/36866556/
# 1  https://pubmed.ncbi.nlm.nih.gov/36839737/
# 2  https://pubmed.ncbi.nlm.nih.gov/36837862/
# 3  https://pubmed.ncbi.nlm.nih.gov/36771738/
# 4  https://pubmed.ncbi.nlm.nih.gov/36771558/
# 5  https://pubmed.ncbi.nlm.nih.gov/36747936/
# 6  https://pubmed.ncbi.nlm.nih.gov/36675191/
# 7  https://pubmed.ncbi.nlm.nih.gov/36672732/
# 8  https://pubmed.ncbi.nlm.nih.gov/36671402/
# 9  https://pubmed.ncbi.nlm.nih.gov/36644848/
